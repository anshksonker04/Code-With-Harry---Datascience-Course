# %% [markdown]
# # Coder of Bangalore
# You ask Sam Altman for 2.2 billion USD in funding, and he makes fun of you in public
#
# He asks you where you live, and finally, after talking to you, gives you a challenging task
#
# Collect raw Instagram data of all OpenAI followers
#
# Answer these questions:
#
# - Who has the maximum posts
# - Who has the maximum followers
# - Who follows the maximum people
# - How many categories (Digital creators, Non-profit foundation, etc do we have? How many people do we have?
# - You have 24 hours!
#
# You then ask for data - he laughs!

# %% [markdown]
# # Data Collection in Indiranagar
# You hire Vijyalaxmi Iyer and Sam Chandra to help with the project. Vijyalaxmi lives all the way in Hebbal, and Sam stays in HSR Layout, so meeting at either place would be a long trip for someone. To keep things fair, you decide to set up a meeting at Rameshwaram Café in Indiranagar, a perfect midway point.
#
# Three of you sit down and lay out the entire project plan. You break the work into two major parts:
#
# Laxmi and Sam will be in charge of collecting the Instagram follower data.
# You will build the Python Script that will process everything.
# By the end of the meeting, everyone is aligned: Laxmi and Sam will focus on accurate data collection, and you’ll focus on making sure the code can handle real-world data seamlessly. The team is ready, the plan is set, and the project officially kicks off.

# %%
with open('finaldata.txt', encoding= 'utf-8') as f:
    data= f.read()

# %%
chunks= data.split('\n\n')
chunks= [c for c in chunks if len(c)>3]

# %%
chunks[1]
# Out:
# 'blrcoder_girl\n150 posts\n6,300 followers\n120 following\nRiya Codes\nTech Creator\n👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes'

# %%
def parse_chunk(chunk):
    try:
        chunk= chunk.strip()
        sep_chunk= chunk.split('\n')
        username= sep_chunk[0]
        no_of_posts= int(sep_chunk[1].split(" post")[0].replace(",", ""))
        no_of_followers= float(sep_chunk[2].split(" follower")[0].replace(",", "").replace("K", "").replace("M", ""))
        if("K" in sep_chunk[2]):
            no_of_followers= int(no_of_followers * 1000)
        elif("M" in sep_chunk[2]):
            no_of_followers= int(no_of_followers * 1000000)
        else:
            no_of_followers= int(no_of_followers)
            
        no_of_following= int(sep_chunk[3].split(" following")[0].replace(",", "").replace("K", "").replace("M", ""))
        if("K" in sep_chunk[3]):
            no_of_following= int(no_of_following * 1000)
        elif("M" in sep_chunk[3]):
            no_of_following= int(no_of_following * 1000000)
        else:
            no_of_following= int(no_of_following)
            
        real_name= sep_chunk[4]
        if(len(sep_chunk)>5):
            type_of_page= sep_chunk[5]
            bio= "\n".join(sep_chunk[6:])
        else:
            type_of_page= "Unknown"
            bio= ""
        # print(username, no_of_posts, no_of_followers, no_of_following, real_name, type_of_page, bio, sep='\n')
        return {"username": username, "posts": no_of_posts, "followers": no_of_followers, "following": no_of_following,
                "name": real_name, "page": type_of_page, "bio": bio}
    except Exception as e:
        print(e, chunk)

# %%
parse_chunk(chunks[1])
# Out:
# {'username': 'blrcoder_girl',
#  'posts': 150,
#  'followers': 6300,
#  'following': 120,
#  'name': 'Riya Codes',
#  'page': 'Tech Creator',
#  'bio': '👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes'}

# %%
all_chunks= []
for chunk in chunks:
    parsed_chunk= parse_chunk(chunk)
    all_chunks.append(parsed_chunk)

# %%
import json
s= json.dumps(all_chunks, indent=4)
with open("data.json", 'w') as f:
    f.write(s)

# %%
# Username with the maximum posts --> self
all_posts= []
for user in all_chunks:
    all_posts.append(user["posts"])

max_posts= max(all_posts)
max_posts

for user in all_chunks:
    if(user['posts']== max_posts):
        max_posts_holder= [user['username'], user['name']]
        break;
print(f"Page with the maximum number of posts is {max_posts_holder[1]}, username= {max_posts_holder[0]} with {max_posts} posts")
# Out:
# Page with the maximum number of posts is Startup Hub Bangalore, username= startuphub_blr with 2300 posts

# %%
# Person with the maximum followers --> self
followers_lookup= [user['followers'] for user in all_chunks]
max_followers= max(followers_lookup)

max_followers_holder= [user for user in all_chunks if(user['followers']==max_followers)]
print(f"Person with the most followers is {max_followers_holder[0]['name']} and its username is {max_followers_holder[0]['username']} with {max_followers} followers")
# Out:
# Person with the most followers is Anuj Singhal and its username is _anujsinghal with 681000 followers

# %%
# Person who follows the maximum people --> self
following_lookup= [user['following'] for user in all_chunks]
max_following= max(following_lookup)

max_following_holder= [user for user in all_chunks if(user['following']==max_following)]
print(f"Person with the most followers is {max_following_holder[0]['name']} and its username is {max_following_holder[0]['username']} with {max_following} following")
# Out:
# Person with the most followers is Rahul | HSR Hustler and its username is bangalore_tech_bro with 890 following

# %%
# Harry's code of maximum posts
max = 0
for chunk in all_chunks:
    if(max < chunk['posts']):
        max = chunk['posts']
        chunk_with_max_post = chunk
print(chunk_with_max_post)

# Harry's code of maximum followers
max = 0
for chunk in all_chunks:
    if(max < chunk['followers']):
        max = chunk['followers']
        chunk_with_max_followers = chunk
print(chunk_with_max_followers)

# Harry's code of maximum following
max = 0
for chunk in all_chunks:
    if(max < chunk['following']):
        max = chunk['following']
        chunk_with_max_following = chunk
print(chunk_with_max_following)
# Out:
# {'username': 'startuphub_blr', 'posts': 2300, 'followers': 45000, 'following': 120, 'name': 'Startup Hub Bangalore', 'page': 'Media', 'bio': '🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter'}
# {'username': '_anujsinghal', 'posts': 1785, 'followers': 681000, 'following': 248, 'name': 'Anuj Singhal', 'page': 'Digital creator', 'bio': 'Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul'}
# {'username': 'bangalore_tech_bro', 'posts': 402, 'followers': 12500, 'following': 890, 'name': 'Rahul | HSR Hustler', 'page': 'Entrepreneur', 'bio': '🚀 Building the next Unicorn in Fintech\n☕ 3rd Wave Coffee addict\n💻 Python | React | AI\n📍 HSR Layout, BLR\nlinktr.ee/rahulbuilds'}

# %%
# How many categories 
categories = set()
for chunk in all_chunks:
    categories.add(chunk['page'])
print(f"There are {len(categories)} categories")
# Out:
# There are 34 categories
